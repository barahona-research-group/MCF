# %%
import matplotlib.pyplot as plt
import networkx as nx
import pickle

from pygenstability import plotting
from pygenstability.contrib.optimal_scales import *
from pygenstability.contrib.sankey import plot_sankey

# %% [markdown]
# # Setup MSF

# %%
import sys
from pathlib import Path

module_path = str(Path.cwd().parents[0])
if module_path not in sys.path:
    sys.path.append(module_path)

from msfiltration import MSF
from msfiltration.msf_bootstrapping import plot_pds, select_scales_pds, msf_bootstrap

# %%
# Set MS parameters
n_time = 200
min_time = -1.5
max_time = 0.5

# %%
# number of bootstraps
B = 20
# number of samples for each bootstrap
n_sample = 150

# %% [markdown]
# # 5th real network: ADK 2RGX

# %%
# Load graph in networkx
root = "/home/tc/OneDrive/Software/MSFiltration/experiments/adk_graph/"
G = nx.read_gpickle(root+"2RGX.gpickle")

# Get sparse adajacency matrix
A = G.adjacency()

# %%
# Compute spring layout
pos = nx.spring_layout(G,seed=5)

# %%
# Plot network
fig, ax = plt.subplots(1,figsize =(10,6))
nx.draw(G,ax=ax,pos=pos, node_size = 4,width = 0.2)

# %%
print(G)
# Out:
# Graph with 3394 nodes and 4494 edges

# %% [markdown]
# # MS Analysis

# %%
# load ms results
with open(root + "ms_adk_2rgx.pkl", 'rb') as handle:
        ms_results = pickle.load(handle)

# initialise new MSF object and compute PH
msf = MSF()
msf.load_ms_results(ms_results)

# %% [markdown]
# full MSF dies after 22 Markov scales (11 minutes)

# %%
# select optimal scales with nvi
identify_optimal_scales(msf.ms_results,criterion_threshold=0,window_size=10)
selected_scales_nvi = msf.log_times[msf.ms_results['selected_partitions']]
# plot nvi summary of ms
plotting.plot_scan(msf.ms_results)

# %%
plot_sankey(all_results = ms_results, optimal_scales=True)

# %% [markdown]
# # Bootstrap MSF

# %%
persistences_bootstrapped = msf_bootstrap(msf.community_ids, msf.log_times, n_sample, B)
# Out:
# Building filtration ...
# 100%|██████████| 150/150 [00:09<00:00, 15.65it/s]
# Computing persistence ...
# Building filtration ...
#  91%|█████████ | 136/150 [00:21<00:02,  6.19it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/tc/OneDrive/Software/MSFiltration/experiments/220609_bootstrap_ADK_2RGX.ipynb Cell 17' in <module>
# ----> <a href='vscode-notebook-cell:/home/tc/OneDrive/Software/MSFiltration/experiments/220609_bootstrap_ADK_2RGX.ipynb#ch0000016?line=0'>1</a> persistences_bootstrapped = msf_bootstrap(msf.community_ids, msf.log_times, n_sample, B)
#
# File ~/OneDrive/Software/MSFiltration/msfiltration/msf_bootstrapping.py:43, in msf_bootstrap(community_ids, log_times, n_sample, B, seed)
#      40 msf_sample.log_times = log_times
#      42 # compute PD for sample
# ---> 43 msf_sample.build_filtration()
#      44 msf_sample.compute_persistence()
#      46 # add persistence of different dimensions to list
#
# File ~/OneDrive/Software/MSFiltration/msfiltration/msfiltration.py:120, in MSF.build_filtration(self, max_dim)
#     116 # cover community by max_dim-simplices when community is larger than max_dim
#     117 for face in itertools.combinations(
#     118     community, min(self.max_dim, s_community)
#     119 ):
# --> 120     self.filtration.insert(list(face), filtration=self.log_times[t])
#
# KeyboardInterrupt:

# %%
# select optimal scales with ph
optimal_scales_ph, gap_width, ax = select_scales_pds(persistences_bootstrapped, msf.log_times, with_plot=True,threshold_abs=0.2,min_gap_width=0.105)

# plot optimal scales in PD
fig, ax = plot_pds(persistences_bootstrapped,msf.log_times,optimal_scales_ph,alpha=0.3)

# %% [markdown]
# # Improve scale selection
